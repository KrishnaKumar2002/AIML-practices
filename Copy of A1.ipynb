# %% [markdown]
# <h2 align=center> You can be a Python Developer !</h2>
# <h1 align=center>Complete the <code>Assignment 1</code></h1>

# %% [markdown]
# **Write a Python Program to calculate the length of a string given**
#
# string  = 'Goods and Prices'

# %%
string = 'Goods and Prices'
len(string)
# Out:
# 16

# %% [markdown]
# **How would you check the Python version you are using in your system ?. Write the code.**

# %%
import sys
sys.version
# Out:
# '3.7.10 (default, May  3 2021, 02:48:31) \n[GCC 7.5.0]'

# %% [markdown]
# **Take the first name and last name from the user and get the last name printed first and the first in the last.**

# %%
a=input("enter your first name")
b=input("enter your last name")
print(b+a)
# Out:
# enter your first nameKrishna
# enter your last nameKumar
# KumarKrishna

# %% [markdown]
# **Lets Say num = 5 , Now calculate the the vaule of ( num  - cube + num - square + num ) using Operators**

# %%
num=5
a=(num**3)+(num**2)+num
print(a)
# Out:
# 155

# %% [markdown]
# **Take 3 integer inputs from the user and return the sum of all the numbers to the user.**

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=int(input("enter a number"))
print(a+b+c)
# Out:
# enter a number1
# enter a number2
# enter a number3
# 6

# %% [markdown]
# **Suppose x and y are the two variables having some values, and x-y = 5 and x + y = 5 . Then Find the value of ( x-square  -   y-square ).**

# %%
x=5
y=0
a=x-y
b=x+y
result=a*b
print(result)
# Out:
# 25

# %% [markdown]
# **Convert the following types to Integer Datatype**
#
# **Numbers :** 45.3, -0, 2.85, 05.45, 23.6

# %%
number=[45.3,-0,2.85,05.45,23.6]
for i in number:
  print(int(i))
# Out:
# 45
# 0
# 2
# 5
# 23

# %% [markdown]
# **Which of the following is a variable and which of the following in a String ?. Discuss**
#
# x = 'variable'
#
# x = 56

# %%
x='variable' is a string because the values  are enclosed within a quotes
x=56 is a integer value because it has no quotes around them

# %% [markdown]
# **Name the Data Types learnt till now in Python**

# %%
int, float, complex, str

# %% [markdown]
# **What does the variable contain after the following code runs?**

# %% [raw]
# variable = 20
# variable + 1

# %%
variable=20
variable+1
print(variable)
# Out:
# 20

# %% [markdown]
# **What will the two expressions will evaluate**?

# %% [raw]
# 'expression_1' + 'expression_2'
# 'expression_1' * 3

# %%
exp_1="krishna"
exp_2="kumar"
print(exp_1+exp_2)
print(exp_1*3)
# Out:
# krishnakumar
# krishnakrishnakrishna

# %% [markdown]
# exp_1+exp_2 simply concatenates the two expressions and combine them into a single exp of string
# whereas the exp_1*3 is used to replicate the exp_1 that is it is used to print the values of exp_1 for three times

# %% [markdown]
# **Why x is a Valid variable and 100 is invalid ?**

# %%
x is a valid variable while 100 is a invalid bcause 100 is a constant whose value will not change and it is a constant while the value of a variable x can be changed so it is a valid variable

# %% [markdown]
# **Why does the statement caiuse an error ?**

# %% [raw]
# print('Artificial Intelligence was first coined in the year = ' + 1999)
#
# ---

# %% [markdown]
# > Indented block

# %% [markdown]
# the following statement causes the error becausse the + sign is used as a separator in the print statement when the data types are of the same types whereas  here the datatypes are of different so it causes the error in such case we should use the , as a separator in the print statement

# %% [markdown]
# Notebook created by: <a href = "https://www.linkedin.com/in/sumitkumarshukla/">Sumit Kumar Shukla</a>
