# %%
import pandas as pd
pd.Series(['a',1]['b',2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-c472890543a3> in <module>()
#       1 import pandas as pd
# ----> 2 pd.Series(['a',1]['b',2])
#
# TypeError: list indices must be integers or slices, not tuple
