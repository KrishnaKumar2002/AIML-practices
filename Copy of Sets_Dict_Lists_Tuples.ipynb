# %% [markdown]
# # <center> Assignment 2

# %% [markdown]
# **What does a Dictionary value with a key 'foo' and a value 42 look like ?**

# %%
a={'fpp':42}
a
# Out:
# {'fpp': 42}

# %% [markdown]
# **Below are two given lists convert it in dictionary**

# %%
b={'keys':Keys,'values':Values}
b
# Out:
# {'keys': ['Ten', 'Twenty', 'Thirty'], 'values': [10, 20, 30]}

# %%
b
# Out:
# {'keys': ['Ten', 'Twenty', 'Thirty'], 'values': [10, 20, 30]}

# %%
Keys = ['Ten','Twenty','Thirty']
Values = [10, 20, 30]

# %% [markdown]
# **Check if a value 200 exists in a dictionary**

# %%
sampleDict = {'a': 100, 'b': 200, 'c': 300}
200 in sampleDict.values()
# Out:
# True

# %% [markdown]
# **Concatenate Lists index-wise**

# %%
list1 = ['A','B','C','D']
list2 = ['a','b','c','d']
list1.extend(list2)
list1
# Out:
# ['A', 'B', 'C', 'D', 'a', 'b', 'c', 'd']

# %% [markdown]
# **Access Grey from the following Tuple**

# %%
Tup = ('orange',['Black','Grey',30],(5, 10, 15))
Tup[1][1]
# Out:
# 'Grey'

# %% [markdown]
# **Swap the following Tuples**

# %%
tuple1 = (11, 22)
tuple2 = (99, 88)
#Expected Output : tuple1 = (99, 88), tuple2= (11, 22)
(tuple1,tuple2)=(tuple2,tuple1)
"tuple1:",tuple1,"tuple2:",tuple2
# Out:
# ('tuple1:', (99, 88), 'tuple2:', (11, 22))

# %% [markdown]
# **Write 2 ways to remove elements from a List**

# %%
#remove()
#pop()
a=[1,2,3,4]
a.remove(2)
a
a.pop()
a
# Out:
# [1, 3]

# %% [markdown]
# **Write a Difference between lists and tuples**

# %% [markdown]
# list:
# list is an ordered collection of heterogeneous data within the square bracket
# elements in a list are mutable
#
# tuple:
# tuple is an ordered collection of heterogeneous data  within the parenthesis
# elements in the tuples are immutable

# %% [markdown]
# **Sort the Following List**

# %%
spam = ['Alice','Dog','Assure','ants','Bob','Carol','Flower']
spam.sort()
spam
# Out:
# ['Alice', 'Assure', 'Bob', 'Carol', 'Dog', 'Flower', 'ants']

# %% [markdown]
# **Find the Maximum of three numbers**

# %%
a=[-3,5,0]
max(a)
# Out:
# 5

# %% [markdown]
# **Give an Example of Replacing Elements of a String**

# %%
a="krishna"
a[1]='m'
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-398324d1c6d3> in <module>()
#       1 a="krishna"
# ----> 2 a[1]='m'
#       3 a
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# in general the strings in python are immutable that is they cannt be changed once they are assigned
# if we try to change it raises an type error

# %% [markdown]
# **Find the uncommon elements from both the sets**

# %%
set1 = {'a','b','c'}
set2 = {'c','d','e'}
set1.symmetric_difference(set2)
# Out:
# {'a', 'b', 'd', 'e'}

# %% [markdown]
# **Check the Divisibilty of a Number by another Number**

# %%
a=12
b=5
if(a%b==0):
  {
      print("divisible")
  }
else:{
    print("non divisible")
}
# Out:
# non divisible

# %% [markdown]
# **use Random Number to generate 5 digit system generated password**

# %%
import random
print(random.randrange(10000,99999))
# Out:
# 13911

# %% [markdown]
# **Calculate th area of a circle with the input of radius given by user**

# %%
def area(radius):
  
  return 3.14*radius*radius
rad=float(input("enter a radius"))
area(rad)
# Out:
# enter a radius2.0
# 12.56

# %% [markdown]
# **What is the difference betwen Append and Insert in List, Explain with Example**

# %%
#append:
#append is a function in python used to add a single element at  the last of the existing list

#extend:
#extend is a function used to add the list at the end of the another list of elements
a=[1,2,3]
a.append(4)
a
a.extend([5,6,7])
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# code created only for practice purpose by Sumit Kumar Shukla
